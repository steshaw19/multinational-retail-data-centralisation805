# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import tabula
import requests
import json
from database_utils import DatabaseConnector
from sqlalchemy import inspect

# %%
db_connector = DatabaseConnector()
source_credentials = db_connector.read_source_db_creds()
source_engine = db_connector.init_source_db_engine(source_credentials)
try:
    print(f"Connection to the {source_credentials['RDS_HOST']} for user {source_credentials['RDS_USER']} created successfully.")
except Exception as ex:
    print("Connection could not be made due to the following error: \n", ex)
# Out:
# Connection to the data-handling-project-readonly.cq2e8zno855e.eu-west-1.rds.amazonaws.com for user aicore_admin created successfully.

# %%
def list_db_tables(source_credentials):
        try:
            # Use the sqalchemy inspector to get table names
            inspector = inspect(source_engine)
            table_names = inspector.get_table_names()
            return table_names
        except Exception as e:
            print(f"Error listing tables: {e}")
            return None
        
list_db_tables(source_credentials)
# Out:
# ['legacy_store_details', 'legacy_users', 'orders_table']

# %%
def read_rds_table(table_name):
        try:
            query = f"SELECT * FROM {table_name}"
            df = pd.read_sql_query(query, source_engine, index_col='index')
            return df
        except Exception as e:
            print(f"Error reading table {table_name}: {e}")
            return None

users_table_df = read_rds_table("legacy_users")

# %%
users_table_df.head()
# Out:
#       first_name last_name date_of_birth                    company  \
# index
# 0       Sigfried     Noack    1990-09-30         Heydrich Junitz KG
# 1            Guy     Allen    1940-12-01                    Fox Ltd
# 2          Harry  Lawrence    1995-08-02  Johnson, Jones and Harris
# 3         Darren   Hussain    1972-09-23                Wheeler LLC
# 4          Garry     Stone    1952-12-20                 Warner Inc
#
#                       email_address  \
# index
# 0                 rudi79@winkler.de
# 1      rhodesclifford@henderson.com
# 2      glen98@bryant-marshall.co.uk
# 3        daniellebryan@thompson.org
# 4           billy14@long-warren.com
#
#                                                  address         country  \
# index
# 0                           Zimmerstr. 1/0\n59015 Gießen         Germany
# 1      Studio 22a\nLynne terrace\nMcCarthymouth\nTF0 9GH  United Kingdom
# 2                     92 Ann drive\nJoanborough\nSK0 6LR  United Kingdom
# 3                 19 Robinson meadow\nNew Tracy\nW22 2QG  United Kingdom
# 4                  3 White pass\nHunterborough\nNN96 4UE  United Kingdom
#
#       country_code       phone_number   join_date  \
# index
# 0               DE   +49(0) 047905356  2018-10-10
# 1               GB    (0161) 496 0674  2001-12-20
# 2               GB  +44(0)121 4960340  2016-12-16
# 3               GB    (0306) 999 0871  2004-02-23
# 4               GB      0121 496 0225  2006-09-01
#
#                                   user_uuid
# index
# 0      93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8
# 1      8fe96c3a-d62d-4eb5-b313-cf12d9126a49
# 2      fc461df4-b919-48b2-909e-55c95a03fe6b
# 3      6104719f-ef14-4b09-bf04-fb0c4620acb0
# 4      9523a6d3-b2dd-4670-a51a-36aebc89f579

# %%
users_table_df.describe(include="all")
# Out:
#        first_name last_name date_of_birth    company email_address address  \
# count       15320     15320         15320      15320         15320   15320
# unique       2178      1192         11360      12105         15300   15300
# top       Michael     Smith          NULL  Smith Inc          NULL    NULL
# freq           57       340            21         22            21      21
#
#                country country_code phone_number join_date user_uuid
# count            15320        15320        15320     15320     15320
# unique              19           20        15092      8268     15300
# top     United Kingdom           GB         NULL      NULL      NULL
# freq              9371         9365           21        21        21

# %%
users_table_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15320 entries, 0 to 1249
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     15320 non-null  object
#  1   last_name      15320 non-null  object
#  2   date_of_birth  15320 non-null  object
#  3   company        15320 non-null  object
#  4   email_address  15320 non-null  object
#  5   address        15320 non-null  object
#  6   country        15320 non-null  object
#  7   country_code   15320 non-null  object
#  8   phone_number   15320 non-null  object
#  9   join_date      15320 non-null  object
#  10  user_uuid      15320 non-null  object
# dtypes: object(11)
# memory usage: 1.4+ MB

# %%
users_table_df.country_code.unique()
# Out:
# array(['DE', 'GB', 'US', 'VSM4IZ4EL3', 'NULL', 'QVUW9JSKY3', 'GGB',
#        '0CU6LW3NKB', 'PG8MOC0UZI', 'NTCGYW8LVC', 'FB13AKRI21',
#        'OS2P9CMHR6', '5D74J6FPFJ', 'LZGTB0T5Z7', 'IM8MN1L9MJ',
#        'RVRFD92E48', 'XKI9UXSCZ1', 'QREF9WLI2A', 'XPVCZE2L8B',
#        '44YAIDY048'], dtype=object)

# %%
users_table_df[~users_table_df['country_code'].isin(["GB", "DE", "US"])]
# Out:
#        first_name   last_name date_of_birth                      company  \
# index
# 752    PYCLKLLC7I  W350SCUD6R    KBTI7FI7Y3                   R7IZUNSQX0
# 867          NULL        NULL          NULL                         NULL
# 1023         NULL        NULL          NULL                         NULL
# 1047   GI4C78KWH0  UTB5PPYFG8    OFH8YGZJWN                   CA1XGS8GZW
# 1807         NULL        NULL          NULL                         NULL
# 2103         NULL        NULL          NULL                         NULL
# 2439         NULL        NULL          NULL                         NULL
# 2597        Peter    Mitchell    1942-01-11  Jennings, Taylor and Davies
# 6526         NULL        NULL          NULL                         NULL
# 2764         NULL        NULL          NULL                         NULL
# 2997   DPAJNJL6PR  B8ZGN8ZJ84    PQPEUO937L                   0YJ2FRMDB4
# 3539   E5139W1FJ3  X88YLZX0JX    7KGJ3C5TSW                   648S19YUFF
# 4987         NULL        NULL          NULL                         NULL
# 5309   XKDVQD7BH2  4YSEX8AY1Z    RQTF5XSXP4                   GKJZ58DTHT
# 5310         NULL        NULL          NULL                         NULL
# 6426   EI10BU4INS  SH6Y92V6IK    D2OZZHWOLK                   LNFBRXXUT4
# 6927         NULL        NULL          NULL                         NULL
# 7747         NULL        NULL          NULL                         NULL
# 8398   I7IJDAPMIM  LUNRZWUKRB    QTVEU5TR8H                   JXKOHA5B8F
# 8451       Hollie      Wilson    1967-11-28                   Hughes Ltd
# 9026   TG6PAO2RAB  PIG6VAZUPM    L3E8OV4UAC                   ROL0IMK6UH
# 9420      Harriet       Berry    1943-12-29                  Vincent LLC
# 10025        NULL        NULL          NULL                         NULL
# 10224  VCQL3ML6ZT  HULT86HONJ    TLSTUEIKI0                   QSS0MWBGFZ
# 10237        NULL        NULL          NULL                         NULL
# 10373  G1SI2RM0KA  67VJEE6DS2    YTC82GP4XE                   M4Z6M30SJ3
# 11002        NULL        NULL          NULL                         NULL
# 11381  31XQ1Z35J9  8LR57D7RZ0    O1LIA1MT1N                   66V9WU2HU1
# 11459        NULL        NULL          NULL                         NULL
# 11615        NULL        NULL          NULL                         NULL
# 11672       Allan        Ryan    1975-02-28                  Herbert LLC
# 11778        NULL        NULL          NULL                         NULL
# 11881        NULL        NULL          NULL                         NULL
# 12110        NULL        NULL          NULL                         NULL
# 12197  2GU3G97VI1  91RL47Q2WC    RQI3KQXFBQ                   D4KULDKYME
# 12359      Cheryl       White    1987-02-17                   Ward-Smith
# 12606        NULL        NULL          NULL                         NULL
# 12640      Joseph      Wright    1951-06-10                   Brooks Inc
# 13135  F3LGJ1NZ0I  IXWSZZ2VPN    1IA43NTJFB                   9WSM9X17XK
# 13879        NULL        NULL          NULL                         NULL
# 14124  DD0K0FUDRY  Q9U9JNG44F    M7HZECVQVC                   DJXWS4B52O
# 14523  YWM71XYN17  PYC56FDP4V    6WAQ2SVK0Q                   WGP4NBYFT6
#
#                          email_address  \
# index
# 752                         3Q791B3VIY
# 867                               NULL
# 1023                              NULL
# 1047                        7HSZB429UK
# 1807                              NULL
# 2103                              NULL
# 2439                              NULL
# 2597                mlambert@riley.com
# 6526                              NULL
# 2764                              NULL
# 2997                        O5Q6D7FDAF
# 3539                        BYU3R2LQF8
# 4987                              NULL
# 5309                        789HWCYC7M
# 5310                              NULL
# 6426                        TFEA83AAHP
# 6927                              NULL
# 7747                              NULL
# 8398                        JK2J6N4DLG
# 8451                  clane@foster.com
# 9026                        EIV7XWUJ8I
# 9420               paige87@knight.info
# 10025                             NULL
# 10224                       1WNILGM5MK
# 10237                             NULL
# 10373                       U1AZKY6URZ
# 11002                             NULL
# 11381                       XASHXWHN80
# 11459                             NULL
# 11615                             NULL
# 11672        simonlambert@barnett.info
# 11778                             NULL
# 11881                             NULL
# 12110                             NULL
# 12197                       YM2YGPR8W1
# 12359                 tony04@smith.com
# 12606                             NULL
# 12640  christianlee@williams-white.com
# 13135                       M5ZDMLPP45
# 13879                             NULL
# 14124                       X29OBIYMTI
# 14523                       6VIJ9KJU8P
#
#                                               address         country  \
# index
# 752                                        YW2YXLOQ5J      I7G4DMDZOZ
# 867                                              NULL            NULL
# 1023                                             NULL            NULL
# 1047                                       63GXGYR3XL      AJ1ENKS3QL
# 1807                                             NULL            NULL
# 2103                                             NULL            NULL
# 2439                                             NULL            NULL
# 2597    849 Collins camp\nSouth Francisland\nAL80 8TD  United Kingdom
# 6526                                             NULL            NULL
# 2764                                             NULL            NULL
# 2997                                       Y1GY1G3EM5      XGI7FM0VBJ
# 3539                                       GOWRW4JCE7      S0E37H52ON
# 4987                                             NULL            NULL
# 5309                                       KJW5WR7W16      XN9NGL5C0B
# 5310                                             NULL            NULL
# 6426                                       XGYW43ZF8B      50KUU3PQUF
# 6927                                             NULL            NULL
# 7747                                             NULL            NULL
# 8398                                       FW3EMRJ25W      EWE3U0DZIV
# 8451         431 Eleanor drive\nLake Yvonne\nEC28 1HL  United Kingdom
# 9026                                       KHJLOAKCW2      GMRBOMI0O1
# 9420   Studio 5\nJamie village\nSouth Howard\nBB0 2QQ  United Kingdom
# 10025                                            NULL            NULL
# 10224                                      R4HMRLEIXV      YOTSVPRBQ7
# 10237                                            NULL            NULL
# 10373                                      N9D1AYQOJ0      5EFAFD0JLI
# 11002                                            NULL            NULL
# 11381                                      NZDOEJPB2M      PNRMPSYR1J
# 11459                                            NULL            NULL
# 11615                                            NULL            NULL
# 11672    Studio 28\nGill drive\nLake Gregory\nRH9 5LP  United Kingdom
# 11778                                            NULL            NULL
# 11881                                            NULL            NULL
# 12110                                            NULL            NULL
# 12197                                      4M2VPXJHBE      RQRB7RMTAD
# 12359               58 Colin mills\nNew Alex\nS2K 5BB  United Kingdom
# 12606                                            NULL            NULL
# 12640            63 O'Neill falls\nWest Dawn\nN9T 5QJ  United Kingdom
# 13135                                      W5VT0DOEKO      3518UD5CE8
# 13879                                            NULL            NULL
# 14124                                      8EK3ZFIGXL      7ZNO5EBALT
# 14523                                      NI3KEEZPTY      T4WBZSW0XI
#
#       country_code      phone_number   join_date  \
# index
# 752     VSM4IZ4EL3        A4Q4HQBI3I  JJ2PDVNPRO
# 867           NULL              NULL        NULL
# 1023          NULL              NULL        NULL
# 1047    QVUW9JSKY3        64ZO0ONUQO  AHN6EKASH3
# 1807          NULL              NULL        NULL
# 2103          NULL              NULL        NULL
# 2439          NULL              NULL        NULL
# 2597           GGB      0121 4960043  1995-07-15
# 6526          NULL              NULL        NULL
# 2764          NULL              NULL        NULL
# 2997    0CU6LW3NKB        DU9UJ42F3E  FYF2FAPZF3
# 3539    PG8MOC0UZI        LJ6H5XBD2A  QH6Z9ZPX37
# 4987          NULL              NULL        NULL
# 5309    NTCGYW8LVC        MUXPJD0BZY  LYVWXBBI6F
# 5310          NULL              NULL        NULL
# 6426    FB13AKRI21        GA2YQ189FL  DM4Q84QZ03
# 6927          NULL              NULL        NULL
# 7747          NULL              NULL        NULL
# 8398    OS2P9CMHR6        G2D0EI6DT3  DOKMYDVV6L
# 8451           GGB    (01632) 960949  2008-10-18
# 9026    5D74J6FPFJ        65I9CX7VF2  YBUYH8T6OE
# 9420           GGB  +44(0)29 2018971  2000-12-25
# 10025         NULL              NULL        NULL
# 10224   LZGTB0T5Z7        6VGTZ6ANEA  SRH5SM36LH
# 10237         NULL              NULL        NULL
# 10373   IM8MN1L9MJ        Y0AKRC4TUP  4JIOCHZY0W
# 11002         NULL              NULL        NULL
# 11381   RVRFD92E48        CLGG66L3JK  3CUODA3HTC
# 11459         NULL              NULL        NULL
# 11615         NULL              NULL        NULL
# 11672          GGB      0121 4960266  1998-05-05
# 11778         NULL              NULL        NULL
# 11881         NULL              NULL        NULL
# 12110         NULL              NULL        NULL
# 12197   XKI9UXSCZ1        35OGAP18JU  8BAER2328P
# 12359          GGB      0141 4960403  2010-02-23
# 12606         NULL              NULL        NULL
# 12640          GGB     +441184960597  2008-10-19
# 13135   QREF9WLI2A        EIP7YUL5CE  U9CRKSTONU
# 13879         NULL              NULL        NULL
# 14124   XPVCZE2L8B        XBL6JO9DU6  9YLGYDEZNV
# 14523   44YAIDY048        QVAV1H2QVH  7PF0SMLXII
#
#                                   user_uuid
# index
# 752                              W43MSCMQ88
# 867                                    NULL
# 1023                                   NULL
# 1047                             BUE34OU973
# 1807                                   NULL
# 2103                                   NULL
# 2439                                   NULL
# 2597   bd3e3bc5-3a25-40dd-ac0f-3f2aaf5814df
# 6526                                   NULL
# 2764                                   NULL
# 2997                             56URKLG01W
# 3539                             A1W2TVMK1S
# 4987                                   NULL
# 5309                             LNRNI6X6VL
# 5310                                   NULL
# 6426                             23WTQ63AET
# 6927                                   NULL
# 7747                                   NULL
# 8398                             8FB8XB78NQ
# 8451   686f612a-0acb-4992-ab03-3913c2011b1e
# 9026                             HEGG0N3ICG
# 9420   0f2b4d28-dcb9-45fe-aff3-7b9135f8d89b
# 10025                                  NULL
# 10224                            AKXDQ62K1V
# 10237                                  NULL
# 10373                            7JTCX4UVLK
# 11002                                  NULL
# 11381                            C7N3K5VF9U
# 11459                                  NULL
# 11615                                  NULL
# 11672  6c20ecd2-499e-4883-85ff-fd50a077cbf3
# 11778                                  NULL
# 11881                                  NULL
# 12110                                  NULL
# 12197                            YIBFXQLD4A
# 12359  347f4f09-7f10-4e5f-b116-05f14bb88944
# 12606                                  NULL
# 12640  c014fa5c-396e-433b-93c1-10ae4d69e897
# 13135                            55II6WK8D2
# 13879                                  NULL
# 14124                            1YOGCW4V46
# 14523                            7PYPXC0PPN

# %% [markdown]
# "GGB" can be replaced with "GB"

# %%
users_table_df["country_code"] = users_table_df["country_code"].str.replace("GGB", "GB")

# %%
users_table_df[~users_table_df['country_code'].isin(["GB", "DE", "US"])]
# Out:
#        first_name   last_name date_of_birth     company email_address  \
# index
# 752    PYCLKLLC7I  W350SCUD6R    KBTI7FI7Y3  R7IZUNSQX0    3Q791B3VIY
# 867          NULL        NULL          NULL        NULL          NULL
# 1023         NULL        NULL          NULL        NULL          NULL
# 1047   GI4C78KWH0  UTB5PPYFG8    OFH8YGZJWN  CA1XGS8GZW    7HSZB429UK
# 1807         NULL        NULL          NULL        NULL          NULL
# 2103         NULL        NULL          NULL        NULL          NULL
# 2439         NULL        NULL          NULL        NULL          NULL
# 6526         NULL        NULL          NULL        NULL          NULL
# 2764         NULL        NULL          NULL        NULL          NULL
# 2997   DPAJNJL6PR  B8ZGN8ZJ84    PQPEUO937L  0YJ2FRMDB4    O5Q6D7FDAF
# 3539   E5139W1FJ3  X88YLZX0JX    7KGJ3C5TSW  648S19YUFF    BYU3R2LQF8
# 4987         NULL        NULL          NULL        NULL          NULL
# 5309   XKDVQD7BH2  4YSEX8AY1Z    RQTF5XSXP4  GKJZ58DTHT    789HWCYC7M
# 5310         NULL        NULL          NULL        NULL          NULL
# 6426   EI10BU4INS  SH6Y92V6IK    D2OZZHWOLK  LNFBRXXUT4    TFEA83AAHP
# 6927         NULL        NULL          NULL        NULL          NULL
# 7747         NULL        NULL          NULL        NULL          NULL
# 8398   I7IJDAPMIM  LUNRZWUKRB    QTVEU5TR8H  JXKOHA5B8F    JK2J6N4DLG
# 9026   TG6PAO2RAB  PIG6VAZUPM    L3E8OV4UAC  ROL0IMK6UH    EIV7XWUJ8I
# 10025        NULL        NULL          NULL        NULL          NULL
# 10224  VCQL3ML6ZT  HULT86HONJ    TLSTUEIKI0  QSS0MWBGFZ    1WNILGM5MK
# 10237        NULL        NULL          NULL        NULL          NULL
# 10373  G1SI2RM0KA  67VJEE6DS2    YTC82GP4XE  M4Z6M30SJ3    U1AZKY6URZ
# 11002        NULL        NULL          NULL        NULL          NULL
# 11381  31XQ1Z35J9  8LR57D7RZ0    O1LIA1MT1N  66V9WU2HU1    XASHXWHN80
# 11459        NULL        NULL          NULL        NULL          NULL
# 11615        NULL        NULL          NULL        NULL          NULL
# 11778        NULL        NULL          NULL        NULL          NULL
# 11881        NULL        NULL          NULL        NULL          NULL
# 12110        NULL        NULL          NULL        NULL          NULL
# 12197  2GU3G97VI1  91RL47Q2WC    RQI3KQXFBQ  D4KULDKYME    YM2YGPR8W1
# 12606        NULL        NULL          NULL        NULL          NULL
# 13135  F3LGJ1NZ0I  IXWSZZ2VPN    1IA43NTJFB  9WSM9X17XK    M5ZDMLPP45
# 13879        NULL        NULL          NULL        NULL          NULL
# 14124  DD0K0FUDRY  Q9U9JNG44F    M7HZECVQVC  DJXWS4B52O    X29OBIYMTI
# 14523  YWM71XYN17  PYC56FDP4V    6WAQ2SVK0Q  WGP4NBYFT6    6VIJ9KJU8P
#
#           address     country country_code phone_number   join_date  \
# index
# 752    YW2YXLOQ5J  I7G4DMDZOZ   VSM4IZ4EL3   A4Q4HQBI3I  JJ2PDVNPRO
# 867          NULL        NULL         NULL         NULL        NULL
# 1023         NULL        NULL         NULL         NULL        NULL
# 1047   63GXGYR3XL  AJ1ENKS3QL   QVUW9JSKY3   64ZO0ONUQO  AHN6EKASH3
# 1807         NULL        NULL         NULL         NULL        NULL
# 2103         NULL        NULL         NULL         NULL        NULL
# 2439         NULL        NULL         NULL         NULL        NULL
# 6526         NULL        NULL         NULL         NULL        NULL
# 2764         NULL        NULL         NULL         NULL        NULL
# 2997   Y1GY1G3EM5  XGI7FM0VBJ   0CU6LW3NKB   DU9UJ42F3E  FYF2FAPZF3
# 3539   GOWRW4JCE7  S0E37H52ON   PG8MOC0UZI   LJ6H5XBD2A  QH6Z9ZPX37
# 4987         NULL        NULL         NULL         NULL        NULL
# 5309   KJW5WR7W16  XN9NGL5C0B   NTCGYW8LVC   MUXPJD0BZY  LYVWXBBI6F
# 5310         NULL        NULL         NULL         NULL        NULL
# 6426   XGYW43ZF8B  50KUU3PQUF   FB13AKRI21   GA2YQ189FL  DM4Q84QZ03
# 6927         NULL        NULL         NULL         NULL        NULL
# 7747         NULL        NULL         NULL         NULL        NULL
# 8398   FW3EMRJ25W  EWE3U0DZIV   OS2P9CMHR6   G2D0EI6DT3  DOKMYDVV6L
# 9026   KHJLOAKCW2  GMRBOMI0O1   5D74J6FPFJ   65I9CX7VF2  YBUYH8T6OE
# 10025        NULL        NULL         NULL         NULL        NULL
# 10224  R4HMRLEIXV  YOTSVPRBQ7   LZGTB0T5Z7   6VGTZ6ANEA  SRH5SM36LH
# 10237        NULL        NULL         NULL         NULL        NULL
# 10373  N9D1AYQOJ0  5EFAFD0JLI   IM8MN1L9MJ   Y0AKRC4TUP  4JIOCHZY0W
# 11002        NULL        NULL         NULL         NULL        NULL
# 11381  NZDOEJPB2M  PNRMPSYR1J   RVRFD92E48   CLGG66L3JK  3CUODA3HTC
# 11459        NULL        NULL         NULL         NULL        NULL
# 11615        NULL        NULL         NULL         NULL        NULL
# 11778        NULL        NULL         NULL         NULL        NULL
# 11881        NULL        NULL         NULL         NULL        NULL
# 12110        NULL        NULL         NULL         NULL        NULL
# 12197  4M2VPXJHBE  RQRB7RMTAD   XKI9UXSCZ1   35OGAP18JU  8BAER2328P
# 12606        NULL        NULL         NULL         NULL        NULL
# 13135  W5VT0DOEKO  3518UD5CE8   QREF9WLI2A   EIP7YUL5CE  U9CRKSTONU
# 13879        NULL        NULL         NULL         NULL        NULL
# 14124  8EK3ZFIGXL  7ZNO5EBALT   XPVCZE2L8B   XBL6JO9DU6  9YLGYDEZNV
# 14523  NI3KEEZPTY  T4WBZSW0XI   44YAIDY048   QVAV1H2QVH  7PF0SMLXII
#
#         user_uuid
# index
# 752    W43MSCMQ88
# 867          NULL
# 1023         NULL
# 1047   BUE34OU973
# 1807         NULL
# 2103         NULL
# 2439         NULL
# 6526         NULL
# 2764         NULL
# 2997   56URKLG01W
# 3539   A1W2TVMK1S
# 4987         NULL
# 5309   LNRNI6X6VL
# 5310         NULL
# 6426   23WTQ63AET
# 6927         NULL
# 7747         NULL
# 8398   8FB8XB78NQ
# 9026   HEGG0N3ICG
# 10025        NULL
# 10224  AKXDQ62K1V
# 10237        NULL
# 10373  7JTCX4UVLK
# 11002        NULL
# 11381  C7N3K5VF9U
# 11459        NULL
# 11615        NULL
# 11778        NULL
# 11881        NULL
# 12110        NULL
# 12197  YIBFXQLD4A
# 12606        NULL
# 13135  55II6WK8D2
# 13879        NULL
# 14124  1YOGCW4V46
# 14523  7PYPXC0PPN

# %%
keep_values = ["GB", "DE", "US"]
users_table_df = users_table_df[users_table_df["country_code"].isin(keep_values)]

# %%
users_table_df.describe(include="all")
# Out:
#        first_name last_name date_of_birth    company      email_address  \
# count       15284     15284         15284      15284              15284
# unique       2162      1176         11344      12089              15284
# top       Michael     Smith    1958-02-02  Smith Inc  rudi79@winkler.de
# freq           57       340             6         22                  1
#
#                              address         country country_code  \
# count                          15284           15284        15284
# unique                         15284               3            3
# top     Zimmerstr. 1/0\n59015 Gießen  United Kingdom           GB
# freq                               1            9371         9371
#
#              phone_number   join_date                             user_uuid
# count               15284       15284                                 15284
# unique              15076        8252                                 15284
# top     +44(0)808 1570796  2006-05-30  93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8
# freq                    3           8                                     1

# %%
users_table_df.duplicated().unique()
# Out:
# array([False])

# %% [markdown]
# There are no duplicated rows in the dataset.

# %%
users_table_df[users_table_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, date_of_birth, company, email_address, address, country, country_code, phone_number, join_date, user_uuid]
# Index: []

# %% [markdown]
# No null data remains
